# %%
#1 
with open("motto.txt", 'w') as file:
    file.write("Fiat Lux!")
with open('motto.txt', 'r') as file:
    print(file.read())
with open("motto.txt", 'a') as file:
    file.write('\n')
    file.write("let there be light!")
with open('motto.txt', 'r') as file:
    print(file.read())
# Out:
# Fiat Lux!
# Fiat Lux!
# let there be light!

# %%
#3
import PyPDF2 
import os

file_handle = open("Sense-and-Sensibility-by-Jane-Austen.pdf", "rb")
pdfReader = PyPDF2.PdfReader(file_handle) 
page_number = len(pdfReader.pages)   
page_object = pdfReader.pages[0]    
page_text = page_object.extract_text()

punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
numbers = '123456789'
frequency_table = {}
for page in pdfReader.pages:
    for word in page_text.split():
        if word in punctuations or word in numbers or word == " " or word == "CHAPTER " or word == " / ":
            if word not in frequency_table:
                frequency_table.keys()
            else:
                frequency_table.values("")

            frequency_table.keys(word)
    page_text.split('\n')
    page_text.split()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 22
#      19         else:
#      20             frequency_table.values("")
# ---> 22         frequency_table.keys(word)
#      23 page_text.split('\n')
#      24 page_text.split()
#
# TypeError: dict.keys() takes no arguments (1 given)

# %%
import PyPDF2
import re
from collections import defaultdict


file_handle = open('Sense-and-Sensibility-by-Jane-Austen.pdf', 'rb')
pdf_reader = PyPDF2.PdfReader(file_handle)


frequency_table = defaultdict(int)


def process_text(text):

    text = re.sub(r'[^\w\s]', '', text)
  
    text = text.lower()
  
    words = text.split()
    return words


for page_num in range(len(pdf_reader.pages)):
    page_object = pdf_reader.pages[page_num]
    page_text = page_object.extract_text()
    lines = page_text.split('\n')
    
    for line in lines:
    
        if re.match(r'chapter\s+\d+', line, re.IGNORECASE):
            continue
        if re.match(r'page\s+\d+', line, re.IGNORECASE):
            continue
        
        words = process_text(line)
        for word in words:
       
            if word.isdigit():
                continue
            frequency_table[word] += 1


file_handle.close()


frequency_table = dict(frequency_table)

print(frequency_table)
# Out:
# {'full': 232, 'text': 200, 'archive': 200, 'httpswwwfulltextarchivecomsense': 1, 'and': 3505, 'sensibility': 13, 'by': 752, 'jane': 2, 'austen': 2, 'the': 4215, 'family': 82, 'of': 3765, 'dashwood': 252, 'had': 1016, 'long': 98, 'been': 432, 'settled': 40, 'in': 1956, 'sussex': 12, 'their': 564, 'estate': 24, 'was': 1971, 'large': 30, 'residence': 11, 'at': 833, 'norland': 77, 'park': 55, 'centre': 2, 'property': 13, 'where': 82, 'for': 1276, 'many': 102, 'generations': 2, 'they': 503, 'lived': 24, 'so': 645, 'respectable': 19, 'a': 2069, 'manner': 52, 'as': 1228, 'to': 4162, 'engage': 15, 'general': 52, 'good': 167, 'opinion': 70, 'surrounding': 6, 'acquaintance': 64, 'late': 28, 'owner': 3, 'this': 398, 'single': 10, 'man': 134, 'who': 268, 'very': 493, 'advanced': 14, 'age': 27, 'years': 57, 'his': 1166, 'life': 66, 'constant': 23, 'companion': 17, 'housekeeper': 4, 'sister': 206, 'but': 799, 'her': 2568, 'death': 11, 'which': 640, 'happened': 29, 'ten': 27, 'before': 190, 'own': 276, 'produced': 29, 'great': 148, 'alteration': 12, 'home': 82, 'supply': 11, 'loss': 20, 'he': 1113, 'invited': 18, 'received': 45, 'into': 115, 'house': 170, 'nephew': 4, 'mr': 181, 'henry': 6, 'legal': 4, 'inheritor': 2, 'person': 69, 'whom': 70, 'intended': 13, 'bequeath': 2, 'it': 1662, 'society': 29, 'niece': 5, 'children': 43, 'old': 51, 'gentlemans': 2, 'days': 46, 'were': 460, 'comfortably': 7, 'spent': 31, 'attachment': 34, 'them': 484, 'all': 627, 'increased': 15, 'attention': 63, 'mrs': 520, 'wishes': 34, 'proceeded': 9, 'not': 1199, 'merely': 21, 'from': 545, 'interest': 46, 'goodness': 11, 'heart': 131, 'gave': 82, 'him': 702, 'every': 380, 'degree': 14, 'solid': 6, 'comfort': 66, 'could': 592, 'receive': 14, 'cheerfulness': 18, 'added': 37, 'relish': 2, 'existence': 10, 'former': 34, 'marriage': 48, 'one': 304, 'son': 33, 'present': 86, 'lady': 152, 'three': 70, 'daughters': 43, 'steady': 6, 'young': 124, 'amply': 5, 'provided': 9, 'fortune': 47, 'mother': 221, 'half': 70, 'devolved': 2, 'on': 689, 'coming': 38, 'likewise': 28, 'soon': 184, 'afterwards': 34, 'wealth': 3, 'therefore': 98, 'succession': 4, 'really': 87, 'important': 12, 'sisters': 102, 'independent': 9, 'what': 404, 'might': 218, 'arise': 9, 'fathers': 11, 'inheriting': 2, 'that': 1352, 'be': 1282, 'small': 37, 'nothing': 172, 'father': 39, 'only': 281, 'seven': 17, 'thousand': 57, 'pounds': 58, 'httpswwwfulltextarchivecomhis': 2, 'disposal': 8, 'remaining': 14, 'moiety': 2, 'first': 168, 'wifes': 6, 'also': 6, 'secured': 11, 'child': 47, 'lifeinterest': 2, 'gentleman': 31, 'died': 9, 'will': 367, 'read': 26, 'like': 71, 'almost': 84, 'other': 183, 'much': 304, 'disappointment': 20, 'pleasure': 64, 'neither': 50, 'unjust': 8, 'nor': 90, 'ungrateful': 3, 'leave': 53, 'nephewbut': 2, 'left': 94, 'such': 360, 'terms': 14, 'destroyed': 5, 'value': 8, 'bequest': 2, 'wished': 57, 'more': 402, 'sake': 39, 'wife': 49, 'than': 374, 'himself': 120, 'or': 336, 'sonbut': 2, 'sons': 6, 'four': 44, 'way': 71, 'no': 549, 'power': 45, 'providing': 3, 'those': 51, 'most': 157, 'dear': 107, 'needed': 7, 'provision': 8, 'any': 409, 'charge': 10, 'sale': 2, 'its': 138, 'valuable': 8, 'woods': 2, 'whole': 61, 'tied': 4, 'up': 106, 'benefit': 5, 'occasional': 5, 'visits': 4, 'with': 978, 'far': 79, 'gained': 15, 'affections': 12, 'uncle': 12, 'attractions': 9, 'are': 203, 'means': 40, 'unusual': 3, 'two': 152, 'an': 355, 'imperfect': 2, 'articulation': 2, 'earnest': 25, 'desire': 25, 'having': 60, 'cunning': 4, 'tricks': 4, 'deal': 39, 'noise': 9, 'outweigh': 5, 'meant': 21, 'unkind': 7, 'however': 157, 'mark': 5, 'affection': 79, 'girls': 20, 'apiece': 8, 'dashwoods': 62, 'severe': 7, 'temper': 24, 'cheerful': 13, 'sanguine': 7, 'reasonably': 12, 'hope': 81, 'live': 44, 'living': 35, 'economically': 2, 'lay': 9, 'considerable': 17, 'sum': 17, 'produce': 9, 'already': 50, 'capable': 23, 'immediate': 25, 'improvement': 8, 'tardy': 2, 'twelvemonth': 10, 'survived': 2, 'longer': 58, 'includin ...

# %%
#Lecture 12 - #1

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
v1 = np.array([2., 2., 4.])

fig = plt.figure()
ax = plt.axes(projection="3d")

z1 = np.linspace(0, v1[0], 1000)
z2 = np.linspace(0, v1[1], 1000)
z3 = np.linspace(0, v1[2], 1000)
ax.plot3D(z1, 0, 0, 'red')
ax.plot3D(0, z2, 0, 'green')
ax.plot3D(0, 0, z3, 'blue')



plt.show()

# %%
#Lecture #12

import numpy as np
a = np.array([[0,1,2,3,4,5],[10,11,12,13,14,15],[20,21,22,23,24,25],[30,31,32,33,34,35],[40,41,42,43,44,45],[50,51,52,53,54,55]])

blue = a[:,1]
print(blue)
pink = a[1, 2:4]
print(pink)
green = a[2:4,4:]
print(green)
orange = [2::2, ::2]
print(orange)
# Out:
#   Cell In[65], line 12
#     orange = [2::2, ::2]
#                ^
# SyntaxError: invalid syntax

# %%
M = np.array([[0, 1, 2], [3, 4, 5]])
def swap_rows(M, a, b):
    c = M[a-1].copy()
    M[a-1] = M[b-1]
    M[b-1] = c
    print(M)
def swap_cols(M, a, b):
    c = M[:,a-1].copy()
    M[:,a-1] = M[:,b-1]
    M[:,b-1] = c
    print(M)
swap_rows(M, 1, 2)
swap_cols(M,1,2)
# Out:
# [[3 4 5]
#  [0 1 2]]
# [[4 3 5]
#  [1 0 2]]

# %%
L = [1, 2, 3, 4]
def set_array(L, rows, cols):
    M = np.array()
    for i in range(1, rows):
        for j in range(1, len(L)):
            M[i,:] = L[j]
    
    print(M)
        
set_array(L, )

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import os
import numpy as np

# Initialization, define some constant
path = os.path.dirname(os.path.abspath(__file__))
filename = path + '/airplane.bmp'
background = plt.imread(filename)

second_hand_length = 200
second_hand_width = 2
minute_hand_length = 150
minute_hand_width = 6
hour_hand_length = 100
hour_hand_width = 10
center = np.array([256, 256])

def clock_hand_vector(angle, length):
    return np.array([length * np.sin(angle), -length * np.cos(angle)])

# draw an image background
fig, ax = plt.subplots()

while True:
    plt.imshow(background)

    # First retrieve the time
    now_time = datetime.now()
    hour = now_time.hour
    if hour>12: hour = hour - 12
    minute = now_time.minute
    second = now_time.second

    # Calculate end points of hour, minute, second

    hour_vector = clock_hand_vector((hour+second/3600)/12*2*np.pi, hour_hand_length)
    minute_vector = clock_hand_vector((minute+second/60)/60*2*np.pi, minute_hand_length)
    second_vector = clock_hand_vector(second/60*2*np.pi, second_hand_length)

    plt.arrow(center[0], center[1], hour_vector[0], hour_vector[1], head_length = 3, linewidth = hour_hand_width, color = 'black')
    plt.arrow(center[0], center[1], minute_vector[0], minute_vector[1], linewidth = minute_hand_width, color = 'black')
    plt.arrow(center[0], center[1], second_vector[0], second_vector[1], linewidth = second_hand_width, color = 'red')

    plt.pause(0.1)
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       7 path = os.path.dirname(os.path.abspath('/airplane.bmp'))
#       8 filename = path + '/airplane.bmp'
# ----> 9 background = plt.imread(filename)
#      11 second_hand_length = 200
#      12 second_hand_width = 2
#
# File /opt/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2597, in imread(fname, format)
#    2593 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2594 def imread(
#    2595         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2596 ) -> np.ndarray:
# -> 2597     return matplotlib.image.imread(fname, format)
#
# File /opt/miniconda3/lib/python3.9/site-packages/matplotlib/image.py:1544, in imread(fname, format)
#    1537 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1538     # Pillow doesn't handle URLs directly.
#    1539     raise ValueError(
#    1540         "Please open the URL for reading and pass the "
#    1541         "result to Pillow, e.g. with "
#    1542         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1543         )
# -> 1544 with img_open(fname) as image:
#    1545     return (_pil_png_to_float_array(image)
#    1546             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1547             pil_to_array(image))
#
# File /opt/miniconda3/lib/python3.9/site-packages/PIL/Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/airplane.bmp'

# %%
from matplotlib import patches
import numpy as np
import matplotlib.pyplot as plt

plt.title("Sample graph!")
label_axis = np.arange(1.0,4.5,0.5).tolist()
plt.xticks(label_axis)

x = np.arange(1.,2.,9,0.001)
x1 = np.arange(2.,3.,0,0.001 )
y0 = 2*x
y1 = -3*x1+10

plt.yticks(label_axis)

plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 9
#       6 label_axis = np.arange(1.0,4.5,0.5).tolist()
#       7 plt.xticks(label_axis)
# ----> 9 x = np.arange(1.,2.,9,0.001)
#      10 x1 = np.arange(2.,3.,0,0.001 )
#      11 y0 = 2*x
#
# TypeError: Cannot interpret '0.001' as a data type

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt

# Create data
linearSeparableFlag = False
x_bias = 6

def toy_2D_samples(x_bias ,linearSeparableFlag):
    label1 = np.array([[1, 0]])
    label2 = np.array([[0, 1]])

    if linearSeparableFlag:

        samples1 = np.random.multivariate_normal([5+x_bias, 0], [[1, 0],[0, 1]], 100)
        samples2 = np.random.multivariate_normal([-5+x_bias, 0], [[1, 0],[0, 1]], 100)

        samples = np.concatenate((samples1, samples2 ), axis =0)
    
        # Plot the data
        plt.plot(samples1[:, 0], samples1[:, 1], 'bo')
        plt.plot(samples2[:, 0], samples2[:, 1], 'rx')
        plt.show()

    else:
        samples1 = np.random.multivariate_normal([5+x_bias, 5], [[1, 0],[0, 1]], 50)
        samples2 = np.random.multivariate_normal([-5+x_bias, -5], [[1, 0],[0, 1]], 50)
        samples3 = np.random.multivariate_normal([-5+x_bias, 5], [[1, 0],[0, 1]], 50)
        samples4 = np.random.multivariate_normal([5+x_bias, -5], [[1, 0],[0, 1]], 50)

        samples = np.concatenate((samples1, samples2, samples3, samples4 ), axis =0)
    
        # Plot the data
        plt.plot(samples1[:, 0], samples1[:, 1], 'bo')
        plt.plot(samples2[:, 0], samples2[:, 1], 'bo')
        plt.plot(samples3[:, 0], samples3[:, 1], 'rx')
        plt.plot(samples4[:, 0], samples4[:, 1], 'rx')
        plt.show()

    label1 = np.array([[1, 0]])
    label2 = np.array([[0, 1]])
    labels1 = np.repeat(label1, 100, axis = 0)
    labels2 = np.repeat(label2, 100, axis = 0)
    labels = np.concatenate((labels1, labels2 ), axis =0)
    return samples, labels

samples, labels = toy_2D_samples(x_bias ,linearSeparableFlag)

# Split training and testing set

randomOrder = np.random.permutation(200)
trainingX = samples[randomOrder[0:100], :]
trainingY = labels[randomOrder[0:100], :]
testingX = samples[randomOrder[100:200], :]
testingY = labels[randomOrder[100:200], :]

model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='sigmoid', use_bias=True))
# model.add(Dense(4, input_shape=(2,), activation='relu', use_bias=True))
model.add(Dense(2, activation='softmax' ))
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['binary_accuracy'])

model.fit(trainingX, trainingY, epochs=500, batch_size=10, verbose=1, validation_split=0.2)

# score = model.evaluate(testingX, testingY, verbose=0)
score = 0
for i in range(100):
    predict_x=model.predict(np.array([testingX[i,:]])) 
    estimate=np.argmax(predict_x,axis=1)

    if testingY[i,estimate] == 1:
        score = score  + 1

    if estimate == 0:
        plt.plot(testingX[i, 0], testingX[i, 1], 'bo')
    else: 
        plt.plot(testingX[i, 0], testingX[i, 1], 'rx')

print('Test accuracy:', score/100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#       3 import numpy as np
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/__init__.py:4
#       1 import os
#       3 # DO NOT EDIT. Generated by api_gen.sh
# ----> 4 from keras.api import DTypePolicy
#       5 from keras.api import FloatDTypePolicy
#       6 from keras.api import Function
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/api/__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/api/activations/__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/activations/__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/activations/activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/backend/__init__.py:9
#       3 if backend() == "torch":
#       4     # When using the torch backend,
#       5     # torch needs to be imported first, otherwise it will segfault
#       6     # upon import.
#       7     import torch
# ----> 9 from keras.src.backend.common.dtypes import result_type
#      10 from keras.src.backend.common.keras_tensor import KerasTensor
#      11 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/backend/common/__init__.py:2
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import KerasVariable
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/backend/common/dtypes.py:5
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)
#      16     "int64",
#      17 )
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/backend/common/variables.py:10
#       8 from keras.src.backend.common.stateless_scope import get_stateless_scope
#       9 from keras.src.backend.common.stateless_scope import in_stateless_scope
# ---> 10 from keras.src.utils.module_utils import tensorflow as tf
#      11 from keras.src.utils.naming import auto_name
#      14 class KerasVariable:
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/utils/__init__.py:1
# ----> 1 from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#       2 from keras.src.utils.dataset_utils import split_dataset
#       3 from keras.src.utils.file_utils import get_file
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/utils/audio_dataset_utils.py:4
#       1 import numpy as np
#       3 from keras.src.api_export import keras_export
# ----> 4 from keras.src.utils import dataset_utils
#       5 from keras.src.utils.module_utils import tensorflow as tf
#       6 from keras.src.utils.module_utils import tensorflow_io as tfio
#
# File /opt/miniconda3/lib/python3.9/site-packages/keras/src/utils/dataset_utils.py:5
#       3 import time
#       4 import warnings
# ----> 5 from multiprocessing.pool import ThreadPool
#       7 import numpy as np
#       9 from keras.src import tree
#
# File /opt/miniconda3/lib/python3.9/multiprocessing/pool.py:30
#      28 from . import util
#      29 from . import get_context, TimeoutError
# ---> 30 from .connection import wait
#      32 #
#      33 # Constants representing the state of a pool
#      34 #
#      36 INIT = "INIT"
#
# File /opt/miniconda3/lib/python3.9/multiprocessing/connection.py:21
#      18 import tempfile
#      19 import itertools
# ---> 21 import _multiprocessing
#      23 from . import util
#      25 from . import AuthenticationError, BufferTooShort
#
# KeyboardInterrupt:

# %%
print("Average recurrence for a note in Corpus: 145.8287153652393")
print("Most frequent note in Corpus appeared: 1627 times")
print("Least frequent note in Corpus appeared: 1 time")
# Out:
# Average recurrence for a note in Corpus: 145.8287153652393
# Most frequent note in Corpus appeared: 1627 times
# Least frequent note in Corpus appeared: 1 time
